# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Import training and testing data

# %%
trainin = pd.read_csv("trainingset.csv")
testin = pd.read_csv("testset.csv")
testinraw = testin 
comin = trainin.append(testin)
ytrainraw = comin['job_performance'][0:20000]
comin = comin.drop('job_performance', axis=1)
r,c = comin.shape
r,c
# Out:
# (40000, 379)

# %% [markdown]
# ### Remove features contain too many NaN

# %%
comin = comin.dropna(axis=1,thresh = 20000) # decrease the number of nan to be <row size /2 in a column
r,c = comin.shape
r,c
# Out:
# (40000, 235)

# %% [markdown]
# ###  Extract numerical features, convert their NaN into mean

# %%
comnum = comin.select_dtypes(include=[np.float32,np.int32,np.float64,np.int64], exclude=None)
comnum = comnum.columns.values.tolist()
comnum = comin[comnum]
comnum = comnum.fillna(comnum.mean())
r,c = comnum.shape
r,c
# Out:
# (40000, 35)

# %% [markdown]
# ### Extract categorical features, convert their NaN into mode, and convert them using One Hot Encoding

# %%
comstr = comin.select_dtypes(include=None, exclude=[np.float32,np.int32,np.float64,np.int64])
comstrmode = comstr.mode()
for column in comstr:
    eachcol = comstr[column]
    eachmode = comstrmode[column][0]
    eachcol.fillna(eachmode, inplace=True)
comstr = pd.get_dummies(comstr)
r,c = comstr.shape
r,c
# Out:
# (40000, 2686)

# %% [markdown]
# ### Combine processed numerical and categorical features

# %%
comin = pd.concat([comnum,comstr],axis=1)
r,c = comin.shape
r,c
# Out:
# (40000, 2721)

# %% [markdown]
# ### From coorelation between features and the lebal, only keep the ones above 0.1

# %%
import seaborn as sns
corrtoy = pd.concat([ytrainraw ,comin[0:20000]],axis=1)
corrtoy = corrtoy.corr() 
corrtoy = corrtoy['job_performance']
corrtoy = np.abs(corrtoy)

# %%
ftokeep = corrtoy[corrtoy > 0.1] 
ftokeep = list(ftokeep.index)
del ftokeep[0]
comin = comin.loc[:,ftokeep]
r,c = comin.shape
r,c
# Out:
# (40000, 241)

# %% [markdown]
# ### Extract Training Data, Validating Data and Testing Data

# %%
from sklearn.model_selection import train_test_split
testin = comin[20000:40000]

trainin = pd.concat([ytrainraw ,comin[0:20000]],axis=1)
trainin, validatein = train_test_split(trainin, test_size = 0.2)

y_train = trainin[['job_performance']]
x_train = trainin.drop('job_performance', axis=1)

y_validate = validatein[['job_performance']]
x_validate = validatein.drop('job_performance', axis=1)

# %% [markdown]
# ### Machine Learning task using Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
modelforest = RandomForestRegressor(random_state=10,n_estimators=61)
modelforest.fit(x_train,np.ravel(y_train))
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=61, n_jobs=None,
#            oob_score=False, random_state=10, verbose=0, warm_start=False)

# %%
from sklearn.metrics import mean_squared_error 
y_predict = modelforest.predict(x_validate)
mse = mean_squared_error(y_predict, y_validate)
print("Random Forest Mean Squared Error: ", round(mse, 2))
# Out:
# Random Forest Mean Squared Error:  29592.19

# %% [markdown]
# ### Output labels for testing data

# %%
y_submit = modelforest.predict(testin)
testinraw['job_performance'] = y_submit
testinraw
# Out:
#                   cntryid           cntryid_e  age_r gender_r  \
# 0                 Ireland             Ireland   25.0   Female
# 1                  Canada    Canada (English)    NaN   Female
# 2                 Germany             Germany    NaN   Female
# 3                 Finland             Finland   18.0   Female
# 4          United Kingdom        England (UK)   61.0   Female
# 5                   Spain               Spain   52.0   Female
# 6                 Germany             Germany    NaN     Male
# 7                   Korea               Korea   41.0     Male
# 8           United States       United States    NaN   Female
# 9           United States       United States    NaN   Female
# 10     Russian Federation  Russian Federation   16.0   Female
# 11                  Spain               Spain   53.0     Male
# 12                 France              France   23.0   Female
# 13                 Poland              Poland   54.0   Female
# 14                  Italy               Italy   54.0     Male
# 15                Germany             Germany    NaN   Female
# 16                 France              France   38.0     Male
# 17                  Japan               Japan   27.0     Male
# 18          United States       United States    NaN     Male
# 19                Germany             Germany    NaN     Male
# 20          United States       United States    NaN   Female
# 21                  Japan               Japan   43.0     Male
# 22                  Korea               Korea   33.0     Male
# 23          United States       United States    NaN     Male
# 24          United States       United States    NaN   Female
# 25          United States       United States    NaN   Female
# 26                 France              France   38.0     Male
# 27                  Japan               Japan   17.0     Male
# 28          United States       United States    NaN   Female
# 29                  Japan               Japan   57.0   Female
# ...                   ...                 ...    ...      ...
# 19970              Israel              Israel   34.0   Female
# 19971              Turkey              Turkey   27.0     Male
# 19972              Turkey              Turkey   35.0     Male
# 19973               Japan               Japan   38.0     Male
# 19974               Italy               Italy   39.0     Male
# 19975              France              France   30.0     Male
# 19976              France              France   30.0     Male
# 19977       United States       United States    NaN     Male
# 19978       United States       United States    NaN     Male
# 19979               Japan               Japan   22.0     Male
# 19980               Japan               Japan   17.0   Female
# 19981             Germany             Germany    NaN     Male
# 19982       United States       United States    NaN     Male
# 19983             Germany             Germany    NaN   Female
# 19984               Japan               Japan   61.0     Male
# 19985               Japan               Japan   42.0   Female
# 19986  Russian Federation  Russian Federation   55.0   Female
# 19987      United Kingdom        England (UK)   43.0   Female
# 19988  Russian Federation  Russian Federation   52.0     Male
# 19989              Poland              Poland   36.0   Female
# 19990       United States       United States    NaN     Male
# 19991       United States       United States    NaN     Male
# 19992              Turkey              Turkey   60.0     Male
# 19993               Japan               Japan   25.0     Male
# 19994  Russian Federation  Russian Federation   48.0     Male
# 19995              France              France   38.0     Male
# 19996       United States       United States    NaN     Male
# 19997               Korea               Korea   28.0     Male
# 19998               Italy               Italy   43.0   Female
# 19999      United Kingdom        England (UK)   52.0     Male
#
#       computerexperience nativespeaker edlevel3        monthlyincpr  \
# 0                    Yes           Yes     High  50 to less than 75
# 1                    Yes            No     High  25 to less than 50
# 2                    Yes           Yes   Medium                 NaN
# 3                    Yes           Yes      Low                 NaN
# 4                    Yes           Yes     High                 NaN
# 5                    Yes           Yes      Low                 NaN
# 6                    Yes           Yes      Low                 NaN
# 7                    Yes           Yes     High          90 or more
# 8                    Yes            No     High  25 to less than 50
# 9                    Yes           Yes      Low                 NaN
# 10                   Yes           Yes      Low                 NaN
# 11                   Yes           Yes      Low                 NaN
# 12                   Yes           Yes     High                 NaN
# 13                   Yes           Yes   Medium                 NaN
# 14                   Yes           Yes   Medium  75 to less than 90
# 15                   Yes            No   Medium                 NaN
# 16                   Yes           Yes   Medium  25 to less than 50
# 17                   Yes           Yes     High  25 to less than 50
# 18                    No           Yes      Low  10 to less than 25
# 19                   Yes           Yes      Low  10 to less than 25
# 20                   Yes           Yes   Medium                 NaN
# 21                   Yes           Yes   Medium  50 to less than 75
# 22                   Yes           Yes     High  75 to less than 90
# 23                   Yes           Yes   Medium  75 to less than 90
# 24                    No           Yes   Medium                 NaN
# 25                   Yes           Yes     High  50 to less than 75
# 26                   Yes            No   Medium  25 to less than 50
# 27                   Yes           Yes      Low                 NaN
# 28                   Yes            No     High          90 or more
# 29                   Yes           Yes   Medium                 NaN
# ...                  ...           ...      ...                 ...
# 19970                Yes           Yes     High  50 to less than 75
# 19971                Yes           Yes     High  75 to less than 90
# 19972                Yes           Yes      Low                 NaN
# 19973                Yes           Yes     High          90 or more
# 19974                Yes           Yes      Low                 NaN
# 19975                Yes           Yes   Medium                 NaN
# 19976                Yes           Yes   Medium                 NaN
# 19977                Yes           Yes   Medium                 NaN
# 19978                Yes           Yes   Medium                 NaN
# 19979                Yes           Yes     High                 NaN
# 19980                Yes           Yes   Medium                 NaN
# 19981                Yes           Yes   Medium  75 to less than 90
# 19982                Yes           Yes   Medium  25 to less than 50
# 19983                Yes            No      Low                 NaN
# 19984                Yes           Yes   Medium                 NaN
# 19985                Yes           Yes   Medium        Less than 10
# 19986                Yes           Yes   Medium                 NaN
# 19987                Yes           Yes   Medium  10 to less than 25
# 19988                Yes           Yes     High                 NaN
# 19989                Yes           Yes      Low                 NaN
# 19990                Yes           Yes   Medium  50 to less than 75
# 19991                Yes           Yes   Medium  75 to less than 90
# 19992                Yes           Yes     High                 NaN
# 19993                Yes           Yes   Medium        Less than 10
# 19994                 No           Yes   Medium  75 to less than 90
# 19995                 No           Yes      Low                 NaN
# 19996                Yes            No   Medium  10 to less than 25
# 19997                Yes           Yes     High  25 to less than 50
# 19998                 No           Yes      Low                 NaN
# 19999                Yes           Yes      Low  25 to less than 50
#
#               yearlyincpr lng_home   ...                           v85  \
# 0      50 to less than 75      999   ...                Strongly agree
# 1      25 to less than 50      999   ...                         Agree
# 2                     NaN      999   ...                Strongly agree
# 3                     NaN      fin   ...                      Disagree
# 4                     NaN      eng   ...                      Disagree
# 5                     NaN      spa   ...    Neither agree nor disagree
# 6                     NaN      999   ...                         Agree
# 7              90 or more      kor   ...    Neither agree nor disagree
# 8      25 to less than 50      999   ...                      Disagree
# 9                     NaN      999   ...                Strongly agree
# 10                    NaN      999   ...                Strongly agree
# 11                    NaN      spa   ...                         Agree
# 12                    NaN      fra   ...                Strongly agree
# 13                    NaN      pol   ...                Strongly agree
# 14     75 to less than 90      999   ...                         Agree
# 15                    NaN      999   ...                         Agree
# 16     50 to less than 75      fra   ...                Strongly agree
# 17     25 to less than 50      jpn   ...                Strongly agree
# 18     10 to less than 25      999   ...                         Agree
# 19           Less than 10      999   ...                         Agree
# 20                    NaN      999   ...                         Agree
# 21     50 to less than 75      jpn   ...    Neither agree nor disagree
# 22     75 to less than 90      kor   ...                         Agree
# 23     75 to less than 90      999   ...                         Agree
# 24                    NaN      999   ...                         Agree
# 25     50 to less than 75      999   ...                         Agree
# 26     25 to less than 50      pol   ...                           NaN
# 27                    NaN      jpn   ...                      Disagree
# 28             90 or more      999   ...                Strongly agree
# 29                    NaN      jpn   ...                      Disagree
# ...                   ...      ...   ...                           ...
# 19970  50 to less than 75      heb   ...                      Disagree
# 19971  75 to less than 90      999   ...                           NaN
# 19972                 NaN      999   ...                           NaN
# 19973          90 or more      jpn   ...                         Agree
# 19974                 NaN      999   ...                Strongly agree
# 19975                 NaN      fra   ...    Neither agree nor disagree
# 19976                 NaN      fra   ...                Strongly agree
# 19977                 NaN      999   ...                Strongly agree
# 19978                 NaN      999   ...                Strongly agree
# 19979                 NaN      jpn   ...                Strongly agree
# 19980                 NaN      jpn   ...                         Agree
# 19981  50 to less than 75      999   ...                      Disagree
# 19982  25 to less than 50      999   ...                         Agree
# 19983                 NaN      999   ...                Strongly agree
# 19984                 NaN      jpn   ...    Neither agree nor disagree
# 19985        Less than 10      jpn   ...    Neither agree nor disagree
# 19986                 NaN      999   ...    Neither agree nor disagree
# 19987  10 to less than 25      eng   ...                Strongly agree
# 19988                 NaN      999   ...                Strongly agree
# 19989                 NaN      pol   ...                         Agree
# 19990  50 to less than 75      999   ...                         Agree
# 19991  75 to less than 90      999   ...                Strongly agree
# 19992                 NaN      999   ...                           NaN
# 19993        Less than 10      jpn   ...                         Agree
# 19994  75 to less than 90      999   ...                         Agree
# 19995                 NaN      fra   ...                         Agree
# 19996  25 to less than 50      999   ...                Strongly agree
# 19997  25 to less than 50      kor   ...             Strongly disagree
# 19998                 NaN      999   ...                Strongly agree
# 19999  25 to less than 50      eng   ...                Strongly agree
#
#                               v50                       v89  \
# 0                           Agree                       NaN
# 1                           Agree                       NaN
# 2                  Strongly agree                       NaN
# 3      Neither agree nor disagree                       NaN
# 4                           Agree                       NaN
# 5                           Agree                       NaN
# 6                           Agree                       NaN
# 7                           Agree                       NaN
# 8                  Strongly agree                       NaN
# 9                  Strongly agree                       NaN
# 10                 Strongly agree                       NaN
# 11                 Strongly agree                       NaN
# 12                       Disagree                       NaN
# 13                 Strongly agree                       NaN
# 14                          Agree                       NaN
# 15                          Agree                       NaN
# 16                          Agree                       NaN
# 17              Strongly disagree                       NaN
# 18                       Disagree                       NaN
# 19                 Strongly agree                       NaN
# 20                          Agree                       NaN
# 21     Neither agree nor disagree                       NaN
# 22                          Agree                       NaN
# 23                          Agree                       NaN
# 24                          Agree                       NaN
# 25                          Agree                       NaN
# 26                            NaN                       NaN
# 27                       Disagree                       NaN
# 28                          Agree                       NaN
# 29                       Disagree                       NaN
# ...                           ...                       ...
# 19970                    Disagree                       NaN
# 19971                         NaN                       NaN
# 19972                         NaN                       NaN
# 19973  Neither agree nor disagree                       NaN
# 19974              Strongly agree                       NaN
# 19975                       Agree                       NaN
# 19976                       Agree                       NaN
# 19977              Strongly agree                       NaN
# 19978              Strongly agree                       NaN
# 19979  Neither agree nor disagree                       NaN
# 19980                    Disagree                       NaN
# 19981  Neither agree nor disagree                       NaN
# 19982              Strongly agree                       NaN
# 19983                       Agree                       NaN
# 19984  Neither agree nor disagree                       NaN
# 19985  Neither agree nor disagree                       NaN
# 19986                       Agree                       NaN
# 19987                       Agree  ISCED 3C 2 years or more
# 19988              Strongly agree                       NaN
# 19989                       Agree                       NaN
# 19990                       Agree                       NaN
# 19991                       Agree                       NaN
# 19992                         NaN                       NaN
# 19993                       Agree                       NaN
# 19994  Neither agree nor disagree                       NaN
# 19995              Strongly agree                       NaN
# 19996                       Agree                       NaN
# 19997                       Agree                       NaN
# 19998              Strongly agree                       NaN
# 19999              Strongly agree                       NaN
#
#                            v127    v239    v224     v71    v105     row  \
# 0                           NaN  9999.0  9996.0  9999.0  9996.0  196612
# 1                           NaN  9999.0  9996.0  9999.0  9999.0    7579
# 2                           NaN  9996.0  9999.0  9996.0  9999.0   24646
# 3                           NaN  9996.0  9999.0  9996.0  9999.0   77790
# 4                           NaN  9996.0  9996.0  9996.0  9996.0  123782
# 5                           NaN  9999.0  9996.0  9999.0  9996.0   15334
# 6                           NaN  9996.0  9996.0  9996.0  9996.0    3050
# 7                           NaN  7322.0  9996.0  1812.0  9996.0   95729
# 8                           NaN  9999.0  9996.0  9999.0  9996.0   27113
# 9                           NaN  9996.0  9996.0  9996.0  9996.0  146202
# 10                          NaN  7313.0  9996.0  3211.0  9996.0  151482
# 11                          NaN  9996.0  8332.0  9996.0  3830.0  188207
# 12                          NaN  9996.0  9996.0  9996.0  9996.0  135803
# 13                          NaN  9996.0  9996.0  9996.0  9996.0  112563
# 14                          NaN  7422.0  9996.0   591.0  9996.0  169909
# 15                          NaN  9996.0  9996.0  9996.0  9996.0   20452
# 16                          NaN  3343.0  9996.0  5520.0  9996.0   46335
# 17                          NaN  7231.0  9996.0  4510.0  9996.0  108884
# 18                          NaN  9999.0  9996.0  9999.0  9996.0   54462
# 19                          NaN  9999.0  9996.0  9999.0  9996.0   43505
# 20                          NaN  9996.0  9999.0  9996.0  9999.0    1847
# 21                          NaN  9129.0  9996.0  8129.0  9996.0  171289
# 22                          NaN  2149.0  9996.0  7110.0  9996.0   59021
# 23                          NaN  9999.0  9996.0  9999.0  9996.0  168431
# 24                          NaN  9996.0  9999.0  9996.0  9999.0   91970
# 25                          NaN  9999.0  9996.0  9999.0  9996.0   96781
# 26                          NaN  7131.0  9996.0  4390.0  9996.0    9325
# 27                          NaN  9996.0  9996.0  9996.0  9996.0  101888
# 28                          NaN  9999.0  9996.0  9999.0  9996.0  158523
# 29                          NaN  9996.0  9996.0  9996.0  9996.0  166270
# ...                         ...     ...     ...     ...     ...     ...
# 19970                       NaN  3352.0  9996.0  8430.0  9996.0   39867
# 19971                       NaN  7411.0  9996.0  8411.0  9996.0   45145
# 19972                       NaN  9996.0  9996.0  9996.0  5510.0   27724
# 19973                       NaN  2433.0  9996.0  2660.0  9996.0   19340
# 19974                       NaN  2512.0  9996.0  6201.0  9996.0   19332
# 19975                       NaN  9996.0  9312.0  9996.0  4210.0   98643
# 19976                       NaN  7512.0  9996.0  1071.0  9996.0  130857
# 19977                       NaN  9996.0  9999.0  9996.0  9999.0  154801
# 19978                       NaN  9996.0  9999.0  9996.0  9999.0  120038
# 19979                       NaN  9996.0  9996.0  9996.0  9996.0  171605
# 19980                       NaN  9996.0  9996.0  9996.0  9996.0  106246
# 19981                       NaN  9999.0  9996.0  9999.0  9996.0  145642
# 19982                       NaN  9999.0  9996.0  9999.0  9996.0   78904
# 19983                       NaN  9996.0  9996.0  9996.0  9996.0  111222
# 19984                       NaN  6113.0  9996.0  9311.0  9996.0  105116
# 19985                       NaN  5321.0  9996.0  8810.0  9996.0   48145
# 19986                       NaN  9996.0  9112.0  9996.0  8121.0   88457
# 19987  ISCED 3C 2 years or more  5311.0  9996.0  8521.0  9996.0  178106
# 19988                       NaN  9996.0  9996.0  9996.0  9996.0  151075
# 19989                       NaN  9996.0  9996.0  9996.0  9996.0   55146
# 19990                       NaN  9999.0  9996.0  9999.0  9996.0   60404
# 19991                       NaN  9999.0  9996.0  9999.0  9996.0   20861
# 19992                       NaN  9996.0  5221.0  9996.0  4711.0   37806
# 19993                       NaN  2355.0  9996.0  8542.0  9996.0   48192
# 19994                       NaN   712.0  9996.0    41.0  9996.0  148013
# 19995                       NaN  9996.0  9312.0  9996.0  8890.0   77678
# 19996                       NaN  9999.0  9996.0  9999.0  9996.0   66957
# 19997                       NaN  4110.0  9996.0  6910.0  9996.0  175111
# 19998                       NaN  9520.0  9996.0  4782.0  9996.0   66737
# 19999                       NaN  8322.0  9996.0  5320.0  9996.0  113458
#
#           uni
# 0      UNI_Author
# 1      UNI_Author
# 2      UNI_Author
# 3      UNI_Author
# 4      UNI_Author
# 5      UNI_Author
# 6      UNI_Author
# 7      UNI_Author
# 8      UNI_Author
# 9      UNI_Author
# 10     UNI_Author
# 11     UNI_Author
# 12     UNI_Author
# 13     UNI_Author
# 14     UNI_Author
# 15     UNI_Author
# 16     UNI_Author
# 17     UNI_Author
# 18     UNI_Author
# 19     UNI_Author
# 20     UNI_Author
# 21     UNI_Author
# 22     UNI_Author
# 23     UNI_Author
# 24     UNI_Author
# 25     UNI_Author
# 26     UNI_Author
# 27     UNI_Author
# 28     UNI_Author
# 29     UNI_Author
# ...       ...
# 19970  UNI_Author
# 19971  UNI_Author
# 19972  UNI_Author
# 19973  UNI_Author
# 19974  UNI_Author
# 19975  UNI_Author
# 19976  UNI_Author
# 19977  UNI_Author
# 19978  UNI_Author
# 19979  UNI_Author
# 19980  UNI_Author
# 19981  UNI_Author
# 19982  UNI_Author
# 19983  UNI_Author
# 19984  UNI_Author
# 19985  UNI_Author
# 19986  UNI_Author
# 19987  UNI_Author
# 19988  UNI_Author
# 19989  UNI_Author
# 19990  UNI_Author
# 19991  UNI_Author
# 19992  UNI_Author
# 19993  UNI_Author
# 19994  UNI_Author
# 19995  UNI_Author
# 19996  UNI_Author
# 19997  UNI_Author
# 19998  UNI_Author
# 19999  UNI_Author
#
# [20000 rows x 380 columns]

# %%
testinraw.to_csv('testset-UNI_Author-submission.csv',index=None)
